# %%
import openai
import base64
from PIL import Image
import io
from IPython.display import display

client = openai.OpenAI(
    api_key="",
    base_url="https://apidev.navigatelabsai.com"
)

response = client.images.generate(
    model="imagen-4.0-generate-001",
    prompt="A modern poster for an AI workshop with futuristic typography, glowing circuits, dark background, professional layout,vibrant colour accents",
    size="1024x1024"
)

image_base64 = response.data[0].b64_json
image_bytes = base64.b64decode(image_base64)

image = Image.open(io.BytesIO(image_bytes))

display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
import openai
import base64

client = openai.OpenAI(
    api_key="",
    base_url="https://apidev.navigatelabsai.com"
)

# Encode image to base64
with open("image2.jpg", "rb") as image_file:
    image_base64 = base64.b64encode(image_file.read()).decode("utf-8")

response = client.chat.completions.create(
    model="gpt-4.1-nano",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "who is the target audience"
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{image_base64}"
                    }
                }
            ]
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# The target audience for this image appears to be professionals and stakeholders in the healthcare, medical research, and biotechnology industries. This may include doctors, researchers, medical students, healthcare administrators, and potential investors interested in advanced medical technology and robotics. The setting seems to focus on cutting-edge medical research or healthcare technology development.
